# %%
# Import the NumPy module.
import numpy as np
import pandas as pd

# %%
np.random.uniform(-90.000, 90.000, size = 2000)
# Out:
# array([ -7.33619946,  46.50323145,  61.23866078, ...,   6.33977353,
#        -19.81031062, -37.99673972])

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 773

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b1284caa8c9b163265d75fd64975fd62

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    

    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
    # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_description})
                          
                          

# If an error is experienced, skip the city.
    except KeyError:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | coruripe
# Processing Record 4 of Set 1 | chokurdakh
# Processing Record 5 of Set 1 | khislavichi
# Processing Record 6 of Set 1 | katsuura
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | husavik
# Processing Record 9 of Set 1 | necochea
# Processing Record 10 of Set 1 | andros town
# Processing Record 11 of Set 1 | butaritari
# Processing Record 12 of Set 1 | havelock
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | krasnoselkup
# Processing Record 15 of Set 1 | tapes
# Processing Record 16 of Set 1 | chadan
# Processing Record 17 of Set 1 | te karaka
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | inhambane
# Processing Record 21 of Set 1 | nhulunbuy
# Processing Record 22 of Set 1 | sosua
# Processing Record 23 of Set 1 | moanda
# Processing Record 24 of Set 1 | ancud
# Processing Record 25 of Set 1 | agadez
# Processing Record 26 of Set 1 | dikson
# Processing Record 27 of Set 1 | carnarvon
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | one hundred mile house
# City not found. Skipping...
# Processing Record 30 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 1 | saint-philippe
# Processing Record 32 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 1 | macusani
# Processing Record 34 of Set 1 | san cristobal
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | busselton
# Processing Record 37 of Set 1 | kargil
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | sechura
# Processing Record 40 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 1 | komsomolskiy
# Processing Record 42 of Set 1 | edd
# Processing Record 43 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 1 | saint-pierre
# Processing Record 45 of Set 1 | cidreira
# Processing Record 46 of Set 1 | karratha
# Processing Record 47 of Set 1 | peleduy
# Processing Record 48 of Set 1 | buala
# Processing Record 49 of Set 1 | ambon
# Processing Record 50 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 2 | alice springs
# Processing Record 2 of Set 2 | nuevo progreso
# Processing Record 3 of Set 2 | paamiut
# Processing Record 4 of Set 2 | bathsheba
# Processing Record 5 of Set 2 | kudahuvadhoo
# Processing Record 6 of Set 2 | isangel
# Processing Record 7 of Set 2 | dubbo
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 2 | trincomalee
# Processing Record 11 of Set 2 | kalmunai
# Processing Record 12 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 2 | port-cartier
# Processing Record 14 of Set 2 | churapcha
# Processing Record 15 of Set 2 | vikravandi
# Processing Record 16 of Set 2 | san blas
# Processing Record 17 of Set 2 | zhezkazgan
# Processing Record 18 of Set 2 | ribeira grande
# Processing Record 19 of Set 2 | srandakan
# Processing Record 20 of Set 2 | kapaa
# Processing Record 21 of Set 2 | kavaratti
# Processing Record 22 of Set 2 | desnogorsk
# Processing Record 23 of Set 2 | nelson bay
# Processing Record 24 of Set 2 | cabo san lucas
# Processing Record 25 of Set 2 | tilbury
# Processing Record 26 of Set 2 | gojo
# Processing Record 27 of Set 2 | new norfolk
# Processing Record 28 of Set 2 | topolobampo
# Processing Record 29 of Set 2 | gizo
# Processing Record 30 of Set 2 | greencastle
# Processing Record 31 of Set 2 | mar del plata
# Processing Record 32 of Set 2 | albany
# Processing Record 33 of Set 2 | ixtapa
# Processing Record 34 of Set 2 | georgetown
# Processing Record 35 of Set 2 | jiuquan
# Processing Record 36 of Set 2 | maracacume
# Processing Record 37 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | quang ngai
# Processing Record 40 of Set 2 | lompoc
# Processing Record 41 of Set 2 | hithadhoo
# Processing Record 42 of Set 2 | meulaboh
# Processing Record 43 of Set 2 | east london
# Processing Record 44 of Set 2 | chake chake
# Processing Record 45 of Set 2 | nampula
# Processing Record 46 of Set 2 | arraial do cabo
# Processing Record 47 of Set 2 | khairpur
# Processing Record 48 of Set 2 | bealanana
# Processing Record 49 of Set 2 | faya
# Processing Record 50 of Set 2 | jamestown
# Processing Record 1 of Set 3 | skegness
# Processing Record 2 of Set 3 | castro
# Processing Record 3 of Set 3 | leh
# Processing Record 4 of Set 3 | mount gambier
# Processing Record 5 of Set 3 | sorata
# Processing Record 6 of Set 3 | voh
# Processing Record 7 of Set 3 | dingle
# Processing Record 8 of Set 3 | tukrah
# Processing Record 9 of Set 3 | ndioum
# Processing Record 10 of Set 3 | marathon
# Processing Record 11 of Set 3 | pioner
# Processing Record 12 of Set 3 | esperance
# Processing Record 13 of Set 3 | bredasdorp
# Processing Record 14 of Set 3 | bluff
# Processing Record 15 of Set 3 | coquimbo
# Processing Record 16 of Set 3 | heinola
# Processing Record 17 of Set 3 | tyulgan
# Processing Record 18 of Set 3 | henties bay
# Processing Record 19 of Set 3 | yamada
# Processing Record 20 of Set 3 | dubenskiy
# City not found. Skipping...
# Processing Record 21 of Set 3 | le port
# Processing Record 22 of Set 3 | ponta do sol
# Processing Record 23 of Set 3 | portland
# Processing Record 24 of Set 3 | sukhobezvodnoye
# Processing Record 25 of Set 3 | jining
# Processing Record 26 of Set 3 | hun
# Processing Record 27 of Set 3 | noumea
# Processing Record 28 of Set 3 | vila velha
# Processing Record 29 of Set 3 | alofi
# Processing Record 30 of Set 3 | severobaykalsk
# Processing Record 31 of Set 3 | caravelas
# Processing Record 32 of Set 3 | barrow
# Processing Record 33 of Set 3 | vaini
# Processing Record 34 of Set 3 | namatanai
# Processing Record 35 of Set 3 | kikwit
# Processing Record 36 of Set 3 | mareeba
# Processing Record 37 of Set 3 | prince rupert
# Processing Record 38 of Set 3 | fairbanks
# Processing Record 39 of Set 3 | khanpur
# Processing Record 40 of Set 3 | farah
# Processing Record 41 of Set 3 | norman wells
# Processing Record 42 of Set 3 | nikolskoye
# Processing Record 43 of Set 3 | pevek
# Processing Record 44 of Set 3 | saint george
# Processing Record 45 of Set 3 | beterou
# Processing Record 46 of Set 3 | haines junction
# Processing Record 47 of Set 3 | kodiak
# Processing Record 48 of Set 3 | beian
# Processing Record 49 of Set 3 | lokosovo
# Processing Record 50 of Set 3 | brasileia
# Processing Record 1 of Set 4 | saldanha
# Processing Record 2 of Set 4 | kontagora
# Processing Record 3 of Set 4 | mahebourg
# Processing Record 4 of Set 4 | pacific grove
# Processing Record 5 of Set 4 | luanda
# Processing Record 6 of Set 4 | paita
# Processing Record 7 of Set 4 | maniwaki
# Processing Record 8 of Set 4 | port keats
# Processing Record 9 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 4 | port elizabeth
# Processing Record 11 of Set 4 | victoria
# Processing Record 12 of Set 4 | oranjemund
# Processing Record 13 of Set 4 | flinders
# Processing Record 14 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 15 of Set 4 | atuona
# Processing Record 16 of Set 4 | vallenar
# Processing Record 17 of Set 4 | pemangkat
# Processing Record 18 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 4 | batagay-alyta
# Processing Record 20 of Set 4 | khandyga
# Processing Record 21 of Set 4 | adrar
# Processing Record 22 of Set 4 | sindon
# Processing Record 23 of Set 4 | chicama
# Processing Record 24 of Set 4 | mount isa
# Processing Record 25 of Set 4 | sur
# Processing Record 26 of Set 4 | seddon
# Processing Record 27 of Set 4 | linchuan
# City not found. Skipping...
# Processing Record 28 of Set 4 | thompson
# Processing Record 29 of Set 4 | sayyan
# Processing Record 30 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 4 | kosh-agach
# Processing Record 32 of Set 4 | lorengau
# Processing Record 33 of Set 4 | kaili
# Processing Record 34 of Set 4 | starychi
# Processing Record 35 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 36 of Set 4 | sambava
# Processing Record 37 of Set 4 | luderitz
# Processing Record 38 of Set 4 | fortuna
# Processing Record 39 of Set 4 | severo-kurilsk
# Processing Record 40 of Set 4 | sterling
# Processing Record 41 of Set 4 | los llanos de aridane
# Processing Record 42 of Set 4 | khatanga
# Processing Record 43 of Set 4 | iqaluit
# Processing Record 44 of Set 4 | tuktoyaktuk
# Processing Record 45 of Set 4 | uniao
# Processing Record 46 of Set 4 | upernavik
# Processing Record 47 of Set 4 | lakota
# Processing Record 48 of Set 4 | tchollire
# Processing Record 49 of Set 4 | ngunguru
# Processing Record 50 of Set 4 | itaueira
# Processing Record 1 of Set 5 | guiratinga
# Processing Record 2 of Set 5 | berlevag
# Processing Record 3 of Set 5 | bengkulu
# Processing Record 4 of Set 5 | carutapera
# Processing Record 5 of Set 5 | camacha
# Processing Record 6 of Set 5 | nanortalik
# Processing Record 7 of Set 5 | visby
# Processing Record 8 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 9 of Set 5 | faanui
# Processing Record 10 of Set 5 | gat
# Processing Record 11 of Set 5 | sitka
# Processing Record 12 of Set 5 | sorland
# Processing Record 13 of Set 5 | yumen
# Processing Record 14 of Set 5 | boa vista
# Processing Record 15 of Set 5 | palmer
# Processing Record 16 of Set 5 | ilulissat
# Processing Record 17 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 5 | antsohihy
# Processing Record 19 of Set 5 | eureka
# Processing Record 20 of Set 5 | port blair
# Processing Record 21 of Set 5 | hervey bay
# Processing Record 22 of Set 5 | nakhon phanom
# Processing Record 23 of Set 5 | jaciara
# Processing Record 24 of Set 5 | ambilobe
# Processing Record 25 of Set 5 | pasni
# Processing Record 26 of Set 5 | bardiyah
# Processing Record 27 of Set 5 | salalah
# Processing Record 28 of Set 5 | san quintin
# Processing Record 29 of Set 5 | piryetos
# City not found. Skipping...
# Processing Record 30 of Set 5 | saskylakh
# Processing Record 31 of Set 5 | mogosesti
# Processing Record 32 of Set 5 | deputatskiy
# Processing Record 33 of Set 5 | labuhan
# Processing Record 34 of Set 5 | leningradskiy
# Processing Record 35 of Set 5 | huangmei
# Processing Record 36 of Set 5 | hobart
# Processing Record 37 of Set 5 | saint-raphael
# Processing Record 38 of Set 5 | lovington
# Processing Record 39 of Set 5 | srednekolymsk
# Processing Record 40 of Set 5 | kysyl-syr
# Processing Record 41 of Set 5 | tuatapere
# Processing Record 42 of Set 5 | buraydah
# Processing Record 43 of Set 5 | bambous virieux
# Processing Record 44 of Set 5 | harper
# Processing Record 45 of Set 5 | sampit
# Processing Record 46 of Set 5 | airai
# Processing Record 47 of Set 5 | hami
# Processing Record 48 of Set 5 | tasiilaq
# Processing Record 49 of Set 5 | avera
# Processing Record 50 of Set 5 | dhidhdhoo
# Processing Record 1 of Set 6 | lahij
# Processing Record 2 of Set 6 | tura
# Processing Record 3 of Set 6 | nicoya
# Processing Record 4 of Set 6 | tiksi
# Processing Record 5 of Set 6 | cabedelo
# Processing Record 6 of Set 6 | hualmay
# Processing Record 7 of Set 6 | constitucion
# Processing Record 8 of Set 6 | souillac
# Processing Record 9 of Set 6 | puerto ayora
# Processing Record 10 of Set 6 | rio verde de mato grosso
# Processing Record 11 of Set 6 | paso de ovejas
# Processing Record 12 of Set 6 | laibin
# Processing Record 13 of Set 6 | seoul
# Processing Record 14 of Set 6 | clyde river
# Processing Record 15 of Set 6 | walvis bay
# Processing Record 16 of Set 6 | fort-shevchenko
# Processing Record 17 of Set 6 | santa rosa
# Processing Record 18 of Set 6 | qaanaaq
# Processing Record 19 of Set 6 | port macquarie
# Processing Record 20 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 6 | namwala
# Processing Record 23 of Set 6 | mogadishu
# Processing Record 24 of Set 6 | yeola
# Processing Record 25 of Set 6 | lincoln
# Processing Record 26 of Set 6 | yar-sale
# Processing Record 27 of Set 6 | burica
# City not found. Skipping...
# Processing Record 28 of Set 6 | ahipara
# Processing Record 29 of Set 6 | marondera
# Processing Record 30 of Set 6 | bud
# Processing Record 31 of Set 6 | saint-augustin
# Processing Record 32 of Set 6 | plymouth
# Processing Record 33 of Set 6 | itarema
# Processing Record 34 of Set 6 | grindavik
# Processing Record 35 of Set 6 | andenes
# Processing Record 36 of Set 6 | bayangol
# Processing Record 37 of Set 6 | ryzdvyanyy
# Processing Record 38 of Set 6 | tete
# Processing Record 39 of Set 6 | san andres
# Processing Record 40 of Set 6 | zhigansk
# Processing Record 41 of Set 6 | kerema
# Processing Record 42 of Set 6 | kokopo
# Processing Record 43 of Set 6 | jalpan
# Processing Record 44 of Set 6 | oxelosund
# Processing Record 45 of Set 6 | bethel
# Processing Record 46 of Set 6 | guasdualito
# Processing Record 47 of Set 6 | hamilton
# Processing Record 48 of Set 6 | sekoma
# Processing Record 49 of Set 6 | nouadhibou
# Processing Record 50 of Set 6 | ust-maya
# Processing Record 1 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 7 | ucluelet
# Processing Record 3 of Set 7 | sao filipe
# Processing Record 4 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 7 | broome
# Processing Record 6 of Set 7 | broken hill
# Processing Record 7 of Set 7 | jacqueville
# Processing Record 8 of Set 7 | asau
# Processing Record 9 of Set 7 | eurajoki
# Processing Record 10 of Set 7 | nanning
# Processing Record 11 of Set 7 | scarborough
# Processing Record 12 of Set 7 | moose factory
# Processing Record 13 of Set 7 | klaksvik
# Processing Record 14 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 7 | kahului
# Processing Record 16 of Set 7 | andilamena
# Processing Record 17 of Set 7 | nevinnomyssk
# Processing Record 18 of Set 7 | acari
# Processing Record 19 of Set 7 | codrington
# Processing Record 20 of Set 7 | diffa
# Processing Record 21 of Set 7 | rincon
# Processing Record 22 of Set 7 | san patricio
# Processing Record 23 of Set 7 | dublin
# Processing Record 24 of Set 7 | solnechnyy
# Processing Record 25 of Set 7 | wuxue
# Processing Record 26 of Set 7 | half moon bay
# Processing Record 27 of Set 7 | arteaga
# Processing Record 28 of Set 7 | manokwari
# Processing Record 29 of Set 7 | palmeirais
# Processing Record 30 of Set 7 | mecca
# Processing Record 31 of Set 7 | jinan
# Processing Record 32 of Set 7 | benghazi
# Processing Record 33 of Set 7 | loralai
# Processing Record 34 of Set 7 | anadyr
# Processing Record 35 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 36 of Set 7 | safaga
# Processing Record 37 of Set 7 | mechanicsville
# Processing Record 38 of Set 7 | batemans bay
# Processing Record 39 of Set 7 | chibombo
# Processing Record 40 of Set 7 | bandar
# Processing Record 41 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 7 | longyearbyen
# Processing Record 43 of Set 7 | mae sai
# Processing Record 44 of Set 7 | valparaiso
# Processing Record 45 of Set 7 | banda
# Processing Record 46 of Set 7 | lasa
# Processing Record 47 of Set 7 | chuy
# Processing Record 48 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 7 | linapacan
# City not found. Skipping...
# Processing Record 50 of Set 7 | burkhala
# City not found. Skipping...
# Processing Record 1 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 8 | banjar
# Processing Record 3 of Set 8 | tigil
# Processing Record 4 of Set 8 | cherskiy
# Processing Record 5 of Set 8 | talnakh
# Processing Record 6 of Set 8 | vuktyl
# Processing Record 7 of Set 8 | ningan
# City not found. Skipping...
# Processing Record 8 of Set 8 | sinegorye
# Processing Record 9 of Set 8 | pitimbu
# Processing Record 10 of Set 8 | nome
# Processing Record 11 of Set 8 | koundara
# Processing Record 12 of Set 8 | sembe
# Processing Record 13 of Set 8 | sile
# Processing Record 14 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 8 | ust-omchug
# Processing Record 16 of Set 8 | bichura
# Processing Record 17 of Set 8 | hasaki
# Processing Record 18 of Set 8 | ler
# Processing Record 19 of Set 8 | sao joao da barra
# Processing Record 20 of Set 8 | taltal
# Processing Record 21 of Set 8 | ntungamo
# Processing Record 22 of Set 8 | leshukonskoye
# Processing Record 23 of Set 8 | the valley
# Processing Record 24 of Set 8 | kushiro
# Processing Record 25 of Set 8 | pisco
# Processing Record 26 of Set 8 | vila franca do campo
# Processing Record 27 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 8 | bondeno
# Processing Record 29 of Set 8 | moron
# Processing Record 30 of Set 8 | arroyo
# Processing Record 31 of Set 8 | springbok
# Processing Record 32 of Set 8 | yakeshi
# Processing Record 33 of Set 8 | provideniya
# Processing Record 34 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 8 | aklavik
# Processing Record 36 of Set 8 | amuntai
# Processing Record 37 of Set 8 | umm lajj
# Processing Record 38 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 39 of Set 8 | taikang
# Processing Record 40 of Set 8 | bilma
# Processing Record 41 of Set 8 | hollola
# Processing Record 42 of Set 8 | karpogory
# Processing Record 43 of Set 8 | kirkuk
# Processing Record 44 of Set 8 | bodden town
# Processing Record 45 of Set 8 | yuty
# Processing Record 46 of Set 8 | rocha
# Processing Record 47 of Set 8 | north bend
# Processing Record 48 of Set 8 | zharkent
# Processing Record 49 of Set 8 | santa ana
# Processing Record 50 of Set 8 | laguna
# Processing Record 1 of Set 9 | puerto escondido
# Processing Record 2 of Set 9 | klichka
# Processing Record 3 of Set 9 | ushtobe
# Processing Record 4 of Set 9 | kingskettle
# Processing Record 5 of Set 9 | kathmandu
# Processing Record 6 of Set 9 | wamba
# Processing Record 7 of Set 9 | labuan
# Processing Record 8 of Set 9 | sol-iletsk
# Processing Record 9 of Set 9 | rosamorada
# Processing Record 10 of Set 9 | ostersund
# Processing Record 11 of Set 9 | shimoda
# Processing Record 12 of Set 9 | hangu
# Processing Record 13 of Set 9 | severo-yeniseyskiy
# Processing Record 14 of Set 9 | rawah
# Processing Record 15 of Set 9 | larsnes
# Processing Record 16 of Set 9 | kuvshinovo
# Processing Record 17 of Set 9 | alekseyevsk
# Processing Record 18 of Set 9 | puerto colombia
# Processing Record 19 of Set 9 | san rafael
# Processing Record 20 of Set 9 | tabas
# Processing Record 21 of Set 9 | hobyo
# Processing Record 22 of Set 9 | padang
# Processing Record 23 of Set 9 | guerrero negro
# Processing Record 24 of Set 9 | aden
# Processing Record 25 of Set 9 | narsaq
# Processing Record 26 of Set 9 | mishan
# Processing Record 27 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 9 | miyako
# Processing Record 29 of Set 9 | sayat
# Processing Record 30 of Set 9 | atar
# Processing Record 31 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 32 of Set 9 | paredon
# Processing Record 33 of Set 9 | sao joao do piaui
# Processing Record 34 of Set 9 | hirara
# Processing Record 35 of Set 9 | vikhorevka
# Processing Record 36 of Set 9 | san jorge
# Processing Record 37 of Set 9 | bhag
# Processing Record 38 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 9 | san juan de flores
# Processing Record 40 of Set 9 | nyurba
# Processing Record 41 of Set 9 | omidiyeh
# Processing Record 42 of Set 9 | geraldton
# Processing Record 43 of Set 9 | lensk
# Processing Record 44 of Set 9 | kutum
# Processing Record 45 of Set 9 | along
# Processing Record 46 of Set 9 | katherine
# Processing Record 47 of Set 9 | thomaston
# Processing Record 48 of Set 9 | buta
# Processing Record 49 of Set 9 | xinan
# Processing Record 50 of Set 9 | vestmannaeyjar
# Processing Record 1 of Set 10 | kimbe
# Processing Record 2 of Set 10 | palana
# Processing Record 3 of Set 10 | tazovskiy
# Processing Record 4 of Set 10 | port lincoln
# Processing Record 5 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 10 | diapaga
# Processing Record 7 of Set 10 | huanren
# Processing Record 8 of Set 10 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 9 of Set 10 | imbituba
# Processing Record 10 of Set 10 | aswan
# Processing Record 11 of Set 10 | porto novo
# Processing Record 12 of Set 10 | brewster
# Processing Record 13 of Set 10 | basoko
# Processing Record 14 of Set 10 | tagusao
# Processing Record 15 of Set 10 | dudinka
# Processing Record 16 of Set 10 | lavrentiya
# Processing Record 17 of Set 10 | sholokhovskiy
# Processing Record 18 of Set 10 | celestun
# Processing Record 19 of Set 10 | braslav
# City not found. Skipping...
# Processing Record 20 of Set 10 | kaya
# Processing Record 21 of Set 10 | chimbote
# Processing Record 22 of Set 10 | kadaya
# Processing Record 23 of Set 10 | westport
# Processing Record 24 of Set 10 | touros
# Processing Record 25 of Set 10 | tornio
# Processing Record 26 of Set 10 | coracao de maria
# Processing Record 27 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 28 of Set 10 | banda aceh
# Processing Record 29 of Set 10 | weligama
# Processing Record 30 of Set 10 | kinshasa
# Processing Record 31 of Set 10 | souris
# Processing Record 32 of Set 10 | alakurtti
# Processing Record 33 of Set 10 | woodward
# Processing Record 34 of Set 10 | umm kaddadah
# Processing Record 35 of Set 10 | madimba
# Processing Record 36 of Set 10 | margate
# Processing Record 37 of Set 10 | mwene-ditu
# Processing Record 38 of Set 10 | promyshlennovskiy
# Processing Record 39 of Set 10 | elko
# Processing Record 40 of Set 10 | nabire
# Processing Record 41 of Set 10 | skaelskor
# Processing Record 42 of Set 10 | college
# Processing Record 43 of Set 10 | winnipeg
# Processing Record 44 of Set 10 | isla mujeres
# Processing Record 45 of Set 10 | markala
# Processing Record 46 of Set 10 | anchorage
# Processing Record 47 of Set 10 | naze
# Processing Record 48 of Set 10 | najran
# Processing Record 49 of Set 10 | plettenberg bay
# Processing Record 50 of Set 10 | itoman
# Processing Record 1 of Set 11 | tongzi
# Processing Record 2 of Set 11 | nacala
# Processing Record 3 of Set 11 | garden city
# Processing Record 4 of Set 11 | vardo
# Processing Record 5 of Set 11 | genhe
# Processing Record 6 of Set 11 | sibolga
# Processing Record 7 of Set 11 | ouesso
# Processing Record 8 of Set 11 | satka
# Processing Record 9 of Set 11 | garowe
# Processing Record 10 of Set 11 | olafsvik
# Processing Record 11 of Set 11 | arcachon
# Processing Record 12 of Set 11 | saint-jean-de-maurienne
# Processing Record 13 of Set 11 | saint anthony
# Processing Record 14 of Set 11 | novonukutskiy
# Processing Record 15 of Set 11 | cap malheureux
# Processing Record 16 of Set 11 | cayenne
# Processing Record 17 of Set 11 | salamanca
# Processing Record 18 of Set 11 | stokmarknes
# Processing Record 19 of Set 11 | mehamn
# Processing Record 20 of Set 11 | salinopolis
# Processing Record 21 of Set 11 | dali
# Processing Record 22 of Set 11 | chabahar
# Processing Record 23 of Set 11 | maldonado
# Processing Record 24 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 11 | praia
# Processing Record 26 of Set 11 | leicester
# Processing Record 27 of Set 11 | bad kreuznach
# Processing Record 28 of Set 11 | bennington
# Processing Record 29 of Set 11 | damghan
# Processing Record 30 of Set 11 | nargana
# Processing Record 31 of Set 11 | thinadhoo
# Processing Record 32 of Set 11 | manzil salim
# Processing Record 33 of Set 11 | aksha
# Processing Record 34 of Set 11 | lgov
# Processing Record 35 of Set 11 | sola
# Processing Record 36 of Set 11 | pietersburg
# Processing Record 37 of Set 11 | vostok
# Processing Record 38 of Set 11 | saint-joseph
# Processing Record 39 of Set 11 | rawson
# Processing Record 40 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 41 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 42 of Set 11 | mbarara
# Processing Record 43 of Set 11 | swellendam
# Processing Record 44 of Set 11 | kavieng
# Processing Record 45 of Set 11 | kaitangata
# Processing Record 46 of Set 11 | heilbron
# Processing Record 47 of Set 11 | koulamoutou
# Processing Record 48 of Set 11 | soyo
# Processing Record 49 of Set 11 | ouro preto do oeste
# Processing Record 50 of Set 11 | korla
# Processing Record 1 of Set 12 | praia da vitoria
# Processing Record 2 of Set 12 | yangambi
# Processing Record 3 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 12 | san ramon
# Processing Record 5 of Set 12 | kodigenahalli
# Processing Record 6 of Set 12 | oliver
# Processing Record 7 of Set 12 | marsh harbour
# Processing Record 8 of Set 12 | nantucket
# Processing Record 9 of Set 12 | kruisfontein
# Processing Record 10 of Set 12 | nijar
# Processing Record 11 of Set 12 | nokaneng
# Processing Record 12 of Set 12 | odweyne
# Processing Record 13 of Set 12 | fraserburgh
# Processing Record 14 of Set 12 | smidovich
# Processing Record 15 of Set 12 | mitsamiouli
# Processing Record 16 of Set 12 | morondava
# Processing Record 17 of Set 12 | manyana
# Processing Record 18 of Set 12 | nichinan
# Processing Record 19 of Set 12 | moyale
# Processing Record 20 of Set 12 | port hedland
# Processing Record 21 of Set 12 | panzhihua
# Processing Record 22 of Set 12 | boueni
# Processing Record 23 of Set 12 | rosarito
# Processing Record 24 of Set 12 | nusaybin
# Processing Record 25 of Set 12 | karasuk
# Processing Record 26 of Set 12 | mocajuba
# Processing Record 27 of Set 12 | butembo
# Processing Record 28 of Set 12 | maroantsetra
# Processing Record 29 of Set 12 | waw
# Processing Record 30 of Set 12 | goma
# Processing Record 31 of Set 12 | durant
# Processing Record 32 of Set 12 | thanh hoa
# Processing Record 33 of Set 12 | mugur-aksy
# Processing Record 34 of Set 12 | gamba
# Processing Record 35 of Set 12 | jieshi
# Processing Record 36 of Set 12 | lyaskelya
# Processing Record 37 of Set 12 | atherton
# Processing Record 38 of Set 12 | changji
# Processing Record 39 of Set 12 | gunjur
# Processing Record 40 of Set 12 | kilmez
# City not found. Skipping...
# Processing Record 41 of Set 12 | neuquen
# Processing Record 42 of Set 12 | daru
# Processing Record 43 of Set 12 | khotkovo
# Processing Record 44 of Set 12 | neiafu
# Processing Record 45 of Set 12 | taoudenni
# Processing Record 46 of Set 12 | hays
# Processing Record 47 of Set 12 | lethem
# Processing Record 48 of Set 12 | ust-tsilma
# Processing Record 49 of Set 12 | barcelos
# Processing Record 50 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 1 of Set 13 | raduzhnyy
# Processing Record 2 of Set 13 | todos santos
# Processing Record 3 of Set 13 | riyadh
# Processing Record 4 of Set 13 | morwell
# Processing Record 5 of Set 13 | marzuq
# Processing Record 6 of Set 13 | mamakan
# Processing Record 7 of Set 13 | hovd
# Processing Record 8 of Set 13 | vanimo
# Processing Record 9 of Set 13 | ozinki
# Processing Record 10 of Set 13 | yoichi
# Processing Record 11 of Set 13 | biak
# Processing Record 12 of Set 13 | shelburne
# Processing Record 13 of Set 13 | guamuchil
# Processing Record 14 of Set 13 | birobidzhan
# Processing Record 15 of Set 13 | evensk
# Processing Record 16 of Set 13 | tenango
# Processing Record 17 of Set 13 | coihaique
# Processing Record 18 of Set 13 | muscle shoals
# Processing Record 19 of Set 13 | ust-nera
# Processing Record 20 of Set 13 | lagoa
# Processing Record 21 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 22 of Set 13 | dumas
# Processing Record 23 of Set 13 | apiai
# Processing Record 24 of Set 13 | kupang
# Processing Record 25 of Set 13 | maputo
# Processing Record 26 of Set 13 | arlit
# Processing Record 27 of Set 13 | merauke
# Processing Record 28 of Set 13 | ulaangom
# Processing Record 29 of Set 13 | lebork
# Processing Record 30 of Set 13 | athens
# Processing Record 31 of Set 13 | yuxia
# Processing Record 32 of Set 13 | manado
# Processing Record 33 of Set 13 | muros
# Processing Record 34 of Set 13 | novoagansk
# Processing Record 35 of Set 13 | cesis
# Processing Record 36 of Set 13 | dayong
# Processing Record 37 of Set 13 | upington
# Processing Record 38 of Set 13 | balabac
# Processing Record 39 of Set 13 | port moresby
# Processing Record 40 of Set 13 | camopi
# Processing Record 41 of Set 13 | beaufort
# Processing Record 42 of Set 13 | artsyz
# Processing Record 43 of Set 13 | campo largo
# Processing Record 44 of Set 13 | saginaw
# Processing Record 45 of Set 13 | andevoranto
# City not found. Skipping...
# Processing Record 46 of Set 13 | tynda
# Processing Record 47 of Set 13 | berlin
# Processing Record 48 of Set 13 | cukai
# Processing Record 49 of Set 13 | kaihua
# Processing Record 50 of Set 13 | weymouth
# Processing Record 1 of Set 14 | young
# Processing Record 2 of Set 14 | vigo
# Processing Record 3 of Set 14 | laizhou
# Processing Record 4 of Set 14 | geilo
# Processing Record 5 of Set 14 | barcelona
# Processing Record 6 of Set 14 | george
# Processing Record 7 of Set 14 | makakilo city
# Processing Record 8 of Set 14 | te anau
# Processing Record 9 of Set 14 | baruun-urt
# Processing Record 10 of Set 14 | copiapo
# Processing Record 11 of Set 14 | talas
# Processing Record 12 of Set 14 | la ronge
# Processing Record 13 of Set 14 | xining
# Processing Record 14 of Set 14 | novochernorechenskiy
# Processing Record 15 of Set 14 | senno
# Processing Record 16 of Set 14 | taloqan
# Processing Record 17 of Set 14 | kenai
# Processing Record 18 of Set 14 | gazli
# Processing Record 19 of Set 14 | waingapu
# Processing Record 20 of Set 14 | namibe
# Processing Record 21 of Set 14 | skjervoy
# Processing Record 22 of Set 14 | charters towers
# Processing Record 23 of Set 14 | elliot lake
# Processing Record 24 of Set 14 | cockburn town
# Processing Record 25 of Set 14 | nadym
# Processing Record 26 of Set 14 | madang
# Processing Record 27 of Set 14 | presidencia roque saenz pena
# Processing Record 28 of Set 14 | gushikawa
# Processing Record 29 of Set 14 | fuerte olimpo
# Processing Record 30 of Set 14 | maine-soroa
# Processing Record 31 of Set 14 | dutse
# Processing Record 32 of Set 14 | tilichiki
# Processing Record 33 of Set 14 | micheweni
# Processing Record 34 of Set 14 | kyzyl
# Processing Record 35 of Set 14 | cagliari
# Processing Record 36 of Set 14 | poronaysk
# Processing Record 37 of Set 14 | colquechaca
# Processing Record 38 of Set 14 | mayumba
# Processing Record 39 of Set 14 | progreso
# Processing Record 40 of Set 14 | rogun
# City not found. Skipping...
# Processing Record 41 of Set 14 | ossora
# Processing Record 42 of Set 14 | isabela
# Processing Record 43 of Set 14 | urucui
# Processing Record 44 of Set 14 | key largo
# Processing Record 45 of Set 14 | lata
# Processing Record 46 of Set 14 | ariquemes
# Processing Record 47 of Set 14 | karakose
# City not found. Skipping...
# Processing Record 48 of Set 14 | karanpura
# Processing Record 49 of Set 14 | melfi
# Processing Record 50 of Set 14 | nacogdoches
# Processing Record 1 of Set 15 | valdosta
# Processing Record 2 of Set 15 | bose
# Processing Record 3 of Set 15 | guilin
# Processing Record 4 of Set 15 | thaba-tseka
# Processing Record 5 of Set 15 | huarmey
# Processing Record 6 of Set 15 | charleville-mezieres
# Processing Record 7 of Set 15 | slave lake
# Processing Record 8 of Set 15 | matai
# Processing Record 9 of Set 15 | zapolyarnyy
# Processing Record 10 of Set 15 | barranca
# Processing Record 11 of Set 15 | soe
# Processing Record 12 of Set 15 | guataqui
# Processing Record 13 of Set 15 | kitimat
# Processing Record 14 of Set 15 | treinta y tres
# Processing Record 15 of Set 15 | chumikan
# Processing Record 16 of Set 15 | douglas
# Processing Record 17 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 18 of Set 15 | borgarnes
# Processing Record 19 of Set 15 | moussoro
# Processing Record 20 of Set 15 | bonavista
# Processing Record 21 of Set 15 | novosergiyevka
# Processing Record 22 of Set 15 | quatre cocos
# Processing Record 23 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 15 | west bay
# Processing Record 25 of Set 15 | kieta
# Processing Record 26 of Set 15 | khapa
# Processing Record 27 of Set 15 | sinnamary
# Processing Record 28 of Set 15 | dzhebariki-khaya
# Processing Record 29 of Set 15 | poletayevo
# Processing Record 30 of Set 15 | havoysund
# Processing Record 31 of Set 15 | skibbereen
# Processing Record 32 of Set 15 | launceston
# Processing Record 33 of Set 15 | maragogi
# Processing Record 34 of Set 15 | metro
# Processing Record 35 of Set 15 | casma
# Processing Record 36 of Set 15 | fuyu
# Processing Record 37 of Set 15 | bonthe
# Processing Record 38 of Set 15 | tadine
# Processing Record 39 of Set 15 | wangou
# Processing Record 40 of Set 15 | turkistan
# Processing Record 41 of Set 15 | nam som
# Processing Record 42 of Set 15 | qasigiannguit
# Processing Record 43 of Set 15 | severodvinsk
# Processing Record 44 of Set 15 | udachnyy
# Processing Record 45 of Set 15 | camana
# Processing Record 46 of Set 15 | rabaul
# Processing Record 47 of Set 15 | chiman
# Processing Record 48 of Set 15 | hambantota
# Processing Record 49 of Set 15 | galesong
# Processing Record 50 of Set 15 | miracema do tocantins
# Processing Record 1 of Set 16 | atbasar
# Processing Record 2 of Set 16 | waipawa
# Processing Record 3 of Set 16 | port hardy
# Processing Record 4 of Set 16 | juneau
# Processing Record 5 of Set 16 | buariki
# City not found. Skipping...
# Processing Record 6 of Set 16 | flagstaff
# Processing Record 7 of Set 16 | miraflores
# Processing Record 8 of Set 16 | robertsport
# Processing Record 9 of Set 16 | kochi
# Processing Record 10 of Set 16 | ugoofaaru
# Processing Record 11 of Set 16 | platteville
# Processing Record 12 of Set 16 | palau
# Processing Record 13 of Set 16 | pangnirtung
# Processing Record 14 of Set 16 | cosala
# Processing Record 15 of Set 16 | mujiayingzi
# Processing Record 16 of Set 16 | rucheng
# Processing Record 17 of Set 16 | negombo
# Processing Record 18 of Set 16 | hofn
# Processing Record 19 of Set 16 | arman
# Processing Record 20 of Set 16 | kendallville
# Processing Record 21 of Set 16 | susanville
# Processing Record 22 of Set 16 | jacareacanga
# Processing Record 23 of Set 16 | dunmore town
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura      NZ -46.19  168.86     55.11        65          99
# 1      Hermanus      ZA -34.42   19.23     39.99        92          85
# 2      Coruripe      BR -10.13  -36.18     74.95        81          74
# 3    Chokurdakh      RU  70.63  147.92     41.32        85         100
# 4   Khislavichi      RU  54.19   32.16     62.15        75          90
# 5      Katsuura      JP  35.13  140.30     86.00        84          40
# 6  Punta Arenas      CL -53.15  -70.92     39.20        86          40
# 7       Husavik      IS  66.04  -17.34     46.40        87          75
# 8      Necochea      AR -38.55  -58.74     43.00        61           0
# 9   Andros Town      BS  24.70  -77.77     86.00        66          20
#
#    Wind Speed Weather Description
# 0       10.65     overcast clouds
# 1        3.18          light rain
# 2       12.77       broken clouds
# 3        4.68     overcast clouds
# 4       13.42     overcast clouds
# 5        9.17    scattered clouds
# 6       29.97    scattered clouds
# 7       10.29       broken clouds
# 8        5.01           clear sky
# 9       10.29          few clouds

# %%
# Create the output file (CSV).
#output_data_file = "Weather_Database/WeatherPy_Database.csv"

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv('WeatherPy_Database.csv')
